# %%
# !pip install boto3
import boto3

# %%
s3 = boto3.client('s3',
    aws_access_key_id='',
    aws_secret_access_key='',
    aws_session_token='',
    region_name='us-east-1'
)

bucket = 'reportbucket-vinoth-128'
local_file = '/content/student-dataset.csv'
s3_key = 'uploaded-ss.txt'

# 2. Upload the file
s3.upload_file(local_file, bucket, s3_key)
print(f"Uploaded to {bucket}/{s3_key}")

# 3. Download the file back (FIXED LINE HERE)
s3.download_file(bucket, s3_key, 'downloaded-student-dataset.csv')
print("Download complete!")
# Out:
# Uploaded to reportbucket-vinoth-128/uploaded-ss.txt
# Download complete!
